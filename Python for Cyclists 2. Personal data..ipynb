# %% [markdown]
# # Python for Cyclists 2. Personal data - heart rate zones, calorie burn, power profile etc
#
#
# ### Contents
# 0. Install and import libraries
# 1. Parse a .fit file and read into Pandas df
# 2. Data cleansing
# 3. Enter personal data
# 4. Heart rate zones
# 5. Calorie burn
# 6. Power profile
#
#
# #### To do:
#
# - [ ] calculate duration based on pandas timedelta
# - [ ] calculate median power
# - [ ] legend for circle graph
# - [ ] .fit file with powerdata
# - [ ] more info on metrics/formula's

# %% [markdown]
# ## 0. Install fitparse and import the python libraries
#
# We use the fitparse library to parse the .fit file.
#
# Please find the github of fitparse project here: http://dtcooper.github.io/python-fitparse/

# %%
#!pip install fitparse

# %%
#import the modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import fitparse

# %% [markdown]
# ## 1a. import the .fit file and read it into pandas dataframe

# %%
# parse the fit file and read it into a list called workout
#source: http://johannesjacob.com/
from fitparse import FitFile
import pandas as pd
import matplotlib.pyplot as plt

fitfile = FitFile('Apeldoorn_Lezyne.fit') ### enter the name of the file here!

while True:
    try:
        fitfile.messages
        break
    except KeyError:
        continue
workout = []
for record in fitfile.get_messages('record'):
    r = {}
    for record_data in record:
        r[record_data.name] = record_data.value
    workout.append(r)

# %%
#read this list into a pandas dataframe
fietsdata = pd.DataFrame(workout)
fietsdata.head()
# Out:
#   accumulated_power  altitude cadence  calories  distance  enhanced_altitude  \
# 0              None      18.0    None       0.0       0.0               18.0
# 1              None      18.0    None       0.0       0.0               18.0
# 2              None      18.0    None       0.0       0.0               18.0
# 3              None      18.0    None       0.0       0.0               18.0
# 4              None      18.0    None       0.0       0.0               18.0
#
#    enhanced_speed grade  heart_rate left_pedal_smoothness left_right_balance  \
# 0           0.000  None       115.0                  None               None
# 1           0.000  None       114.0                  None               None
# 2           0.601  None       114.0                  None               None
# 3           1.656  None       113.0                  None               None
# 4           0.000  None       113.0                  None               None
#
#   left_torque_effectiveness  position_lat  position_long power  \
# 0                      None   624666222.0     58001884.0  None
# 1                      None   624666222.0     58001884.0  None
# 2                      None   624666222.0     58001884.0  None
# 3                      None   624666222.0     58001784.0  None
# 4                      None   624666302.0     58001725.0  None
#
#   right_pedal_smoothness right_torque_effectiveness  speed  temperature  \
# 0                   None                       None  0.000           21
# 1                   None                       None  0.000           21
# 2                   None                       None  0.601           21
# 3                   None                       None  1.656           21
# 4                   None                       None  0.000           21
#
#             timestamp
# 0 2021-03-07 08:53:44
# 1 2021-03-07 08:53:44
# 2 2021-03-07 08:53:45
# 3 2021-03-07 08:53:46
# 4 2021-03-07 08:53:47

# %% [markdown]
# ## 2. Data cleaning

# %%
fietsdata.dtypes
# Out:
# accumulated_power                     object
# altitude                             float64
# cadence                               object
# calories                             float64
# distance                             float64
# enhanced_altitude                    float64
# enhanced_speed                       float64
# grade                                 object
# heart_rate                           float64
# left_pedal_smoothness                 object
# left_right_balance                    object
# left_torque_effectiveness             object
# position_lat                         float64
# position_long                        float64
# power                                 object
# right_pedal_smoothness                object
# right_torque_effectiveness            object
# speed                                float64
# temperature                            int64
# timestamp                     datetime64[ns]
# dtype: object

# %%
# convert m/s to km/h
# * 3600s/ 1000 = 3.6
fietsdata['speed_kmh'] = fietsdata['enhanced_speed'] *3.6
fietsdata.head() # check new column speed_kmh at right
# Out:
#   accumulated_power  altitude cadence  calories  distance  enhanced_altitude  \
# 0              None      18.0    None       0.0       0.0               18.0
# 1              None      18.0    None       0.0       0.0               18.0
# 2              None      18.0    None       0.0       0.0               18.0
# 3              None      18.0    None       0.0       0.0               18.0
# 4              None      18.0    None       0.0       0.0               18.0
#
#    enhanced_speed grade  heart_rate left_pedal_smoothness  ...  \
# 0           0.000  None       115.0                  None  ...
# 1           0.000  None       114.0                  None  ...
# 2           0.601  None       114.0                  None  ...
# 3           1.656  None       113.0                  None  ...
# 4           0.000  None       113.0                  None  ...
#
#   left_torque_effectiveness position_lat  position_long  power  \
# 0                      None  624666222.0     58001884.0   None
# 1                      None  624666222.0     58001884.0   None
# 2                      None  624666222.0     58001884.0   None
# 3                      None  624666222.0     58001784.0   None
# 4                      None  624666302.0     58001725.0   None
#
#   right_pedal_smoothness right_torque_effectiveness  speed  temperature  \
# 0                   None                       None  0.000           21
# 1                   None                       None  0.000           21
# 2                   None                       None  0.601           21
# 3                   None                       None  1.656           21
# 4                   None                       None  0.000           21
#
#             timestamp speed_kmh
# 0 2021-03-07 08:53:44    0.0000
# 1 2021-03-07 08:53:44    0.0000
# 2 2021-03-07 08:53:45    2.1636
# 3 2021-03-07 08:53:46    5.9616
# 4 2021-03-07 08:53:47    0.0000
#
# [5 rows x 21 columns]

# %%
#Convert position_long and position_lat to degrees instead of semicircles
fietsdata['pos_lat'] = fietsdata['position_lat']*  (180 / 2**31)
fietsdata['pos_long'] = fietsdata['position_long']*  (180 / 2**31)
fietsdata.head()
# Out:
#   accumulated_power  altitude cadence  calories  distance  enhanced_altitude  \
# 0              None      18.0    None       0.0       0.0               18.0
# 1              None      18.0    None       0.0       0.0               18.0
# 2              None      18.0    None       0.0       0.0               18.0
# 3              None      18.0    None       0.0       0.0               18.0
# 4              None      18.0    None       0.0       0.0               18.0
#
#    enhanced_speed grade  heart_rate left_pedal_smoothness  ... position_long  \
# 0           0.000  None       115.0                  None  ...    58001884.0
# 1           0.000  None       114.0                  None  ...    58001884.0
# 2           0.601  None       114.0                  None  ...    58001884.0
# 3           1.656  None       113.0                  None  ...    58001784.0
# 4           0.000  None       113.0                  None  ...    58001725.0
#
#   power  right_pedal_smoothness  right_torque_effectiveness  speed  \
# 0  None                    None                        None  0.000
# 1  None                    None                        None  0.000
# 2  None                    None                        None  0.601
# 3  None                    None                        None  1.656
# 4  None                    None                        None  0.000
#
#   temperature           timestamp  speed_kmh    pos_lat  pos_long
# 0          21 2021-03-07 08:53:44     0.0000  52.358918  4.861662
# 1          21 2021-03-07 08:53:44     0.0000  52.358918  4.861662
# 2          21 2021-03-07 08:53:45     2.1636  52.358918  4.861662
# 3          21 2021-03-07 08:53:46     5.9616  52.358918  4.861653
# 4          21 2021-03-07 08:53:47     0.0000  52.358925  4.861648
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 3.Personalisation

# %%
# Script to enter your age and weight
weight = int(input("Please enter your weight: "))
age = int(input("Please enter your age: "))
at= int(input("Please enter your aerobic treshold: "))
# Out:
# Please enter your weight: 95
# Please enter your age: 46
# Please enter your aerobic treshold: 173

# %% [markdown]
# ## 4. Heart rate zones

# %%
# Enter aerobic treshold (at)

d1_lower = int(at * 0.7)
d2_lower = int(at * 0.8)
d3_lower = int(at * 0.9)

print("Your heart rate zones are:")
print("d0 < " +str(d1_lower))
print('d1 = '+ str(d1_lower)+ ' - '+str(d2_lower))
print('d2 = '+ str(d2_lower)+ ' - '+str(d3_lower))
print('d3 = '+ str(d3_lower)+ ' - '+str(at))
print('at = '+ str(at))
print("at+ > " +str(at))
# Out:
# Your heart rate zones are:
# d0 < 121
# d1 = 121 - 138
# d2 = 138 - 155
# d3 = 155 - 173
# at = 173
# at+ > 173

# %%
# add a new column to the datafield containing the heart rate zones
fietsdata['hr_zone'] = pd.cut(fietsdata.heart_rate, bins=[0, d1_lower,d2_lower,d3_lower,at, 220], labels=['d0', 'd1', 'd2','d3', 'at+'])
fietsdata.hr_zone
# Out:
# 0       d0
# 1       d0
# 2       d0
# 3       d0
# 4       d0
#         ..
# 6290    d1
# 6291    d1
# 6292    d1
# 6293    d1
# 6294    d1
# Name: hr_zone, Length: 6295, dtype: category
# Categories (5, object): ['d0' < 'd1' < 'd2' < 'd3' < 'at+']

# %%
#check to see the new dtype category for hr_zone
fietsdata.dtypes
# Out:
# accumulated_power                     object
# altitude                             float64
# cadence                               object
# calories                             float64
# distance                             float64
# enhanced_altitude                    float64
# enhanced_speed                       float64
# grade                                 object
# heart_rate                           float64
# left_pedal_smoothness                 object
# left_right_balance                    object
# left_torque_effectiveness             object
# position_lat                         float64
# position_long                        float64
# power                                 object
# right_pedal_smoothness                object
# right_torque_effectiveness            object
# speed                                float64
# temperature                            int64
# timestamp                     datetime64[ns]
# speed_kmh                            float64
# pos_lat                              float64
# pos_long                             float64
# hr_zone                             category
# dtype: object

# %%
#create a new dataframe 'zones' with heart rate data
counts = fietsdata.hr_zone.value_counts()
per    = fietsdata.hr_zone.value_counts(normalize=True).round(3)
percent100 = fietsdata.hr_zone.value_counts(normalize=True).mul(100).round(1).astype(str)+'%'
zones = pd.DataFrame({'counts': counts, 'fraction': per, 'percentage': percent100})
zones
# Out:
#      counts  fraction percentage
# d3     4038     0.642      64.2%
# d2     1917     0.305      30.5%
# d1      286     0.045       4.5%
# at+      26     0.004       0.4%
# d0       22     0.003       0.3%

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
#labels = 'd2', 'd1', 'd3', 'd3', 'at+' TO DO CREATE LABELS or LEGEND
sizes = fietsdata.hr_zone.value_counts(normalize=True).round(3)
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, autopct='%1.1f%%',
        shadow=True, startangle=90, normalize=False)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show() # show image

# %% [markdown]
# ## 5. Calories burned

# %% [markdown]
# ### 5a. Calories burned based on Powermeter data

# %%
# watt * tijd = 
# watt = 1 joule/seconde

# Som (alle powermetingen)= totaal vermogen geleverd aan fiets eenheid: joule / kilojoule
# total_energy = sum['power']

total_energy = fietsdata['power'].sum()

# convert watt to kcal = 1 kilojoule = 0.239 kilocalorie
energy_kcal = total_energy * 0.239 / 1000

# Efficiency body = 21%
energy_used = energy_kcal / 0.21
text = "You've burned {:.0f} kcal"
print(text.format(energy_used))
# Out:
# You've burned 0 kcal

# %% [markdown]
# ### 5b. Calories burned based on heart rate

# %%
#first calculate the time on the bike
timetable = (fietsdata['timestamp'])
starttime= timetable.iloc[0]
endtime= timetable.iloc[-1]
#starttijd = timetable.iloc[1,0]
#print(starttijd

duration = endtime-starttime

print("Total duration was: "+ str(duration))
# Out:
# Total duration was: 0 days 04:22:44

# %%
#source: http://www.shapesense.com/fitness-exercise/calculators/heart-rate-based-calorie-burn-calculator.shtml
HR= avg_heart_rate= fietsdata['heart_rate'].mean()# gemiddelde heartrate
W = weight
A = age
T = 6 #convert pandas timedelta to real time in hours
Calorie_burned_man = ((-55.0969 + (0.6309 * HR) + (0.1988 * W) + (0.2017 * A)) / 4.184) * 60 * T
text = "You've burned {:.0f} kcal."
print(text.format(Calorie_burned_man))
# Out:
# You've burned 6101 kcal.

# %% [markdown]
# ## 6. Power profile

# %%
power_profile = med_power / weight  # define medium power
print("Your power profile was "+ str(round(power_profile,2)) + ' W/kg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-33de01d2b967> in <module>
# ----> 1 power_profile = med_power / weight  # define medium power
#       2 print("Your power profile was "+ str(round(power_profile,2)) + ' W/kg')
#
# NameError: name 'med_power' is not defined
